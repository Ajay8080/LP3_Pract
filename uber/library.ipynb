# %%
pip install sklearn.preprocessing
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement sklearn.preprocessing (from versions: none)
# ERROR: No matching distribution found for sklearn.preprocessing

# %%
pip install StandardScaler
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#      ---------------------------------------- 0.0/55.8 kB ? eta -:--:--
#      -------------------- ----------------- 30.7/55.8 kB 660.6 kB/s eta 0:00:01
#      ---------------------------------- --- 51.2/55.8 kB 650.2 kB/s eta 0:00:01
#      -------------------------------------- 55.8/55.8 kB 414.5 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/60.4 kB ? eta -:--:--
#      -------------------- ------------------- 30.7/60.4 kB ? eta -:--:--
#      -------------------- ------------------- 30.7/60.4 kB ? eta -:--:--
#      -------------------- ------------------- 30.7/60.4 kB ? eta -:--:--
# ...

# %%
pip install tabulate
# Out:
# ...
#   WARNING: The script tabulate.exe is installed in 'c:\Users\DELL\AppData\Local\Programs\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...
